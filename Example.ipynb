# %%
import torch
import torch.nn as nn

# %%
! pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import load_resnet

# %%
resnet18 = load_resnet.ResNet18()

# %%
load_resnet.summarize(resnet18, (4, 3, 224, 224))
# Out:
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                                    [4, 3, 224, 224]     [4, 1000]            --                   True
# ├─Conv2d (conv1)                                   [4, 3, 224, 224]     [4, 64, 112, 112]    9,472                True
# ├─BatchNorm2d (bn1)                                [4, 64, 112, 112]    [4, 64, 112, 112]    128                  True
# ├─ReLU (relu)                                      [4, 64, 112, 112]    [4, 64, 112, 112]    --                   --
# ├─MaxPool2d (maxpool)                              [4, 64, 112, 112]    [4, 64, 56, 56]      --                   --
# ├─Sequential (layer1)                              [4, 64, 56, 56]      [4, 64, 56, 56]      --                   True
# │    └─Block (0)                                   [4, 64, 56, 56]      [4, 64, 56, 56]      4,288                True
# ...

# %%
resnet34 = load_resnet.ResNet34()
load_resnet.summarize(resnet34, (4, 3, 224, 224))
# Out:
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                                    [4, 3, 224, 224]     [4, 1000]            --                   True
# ├─Conv2d (conv1)                                   [4, 3, 224, 224]     [4, 64, 112, 112]    9,472                True
# ├─BatchNorm2d (bn1)                                [4, 64, 112, 112]    [4, 64, 112, 112]    128                  True
# ├─ReLU (relu)                                      [4, 64, 112, 112]    [4, 64, 112, 112]    --                   --
# ├─MaxPool2d (maxpool)                              [4, 64, 112, 112]    [4, 64, 56, 56]      --                   --
# ├─Sequential (layer1)                              [4, 64, 56, 56]      [4, 64, 56, 56]      --                   True
# │    └─Block (0)                                   [4, 64, 56, 56]      [4, 64, 56, 56]      4,288                True
# ...

# %%
resnet50 = load_resnet.ResNet50()
load_resnet.summarize(resnet50, (4, 3, 224, 224))
# Out:
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                                    [4, 3, 224, 224]     [4, 1000]            --                   True
# ├─Conv2d (conv1)                                   [4, 3, 224, 224]     [4, 64, 112, 112]    9,472                True
# ├─BatchNorm2d (bn1)                                [4, 64, 112, 112]    [4, 64, 112, 112]    128                  True
# ├─ReLU (relu)                                      [4, 64, 112, 112]    [4, 64, 112, 112]    --                   --
# ├─MaxPool2d (maxpool)                              [4, 64, 112, 112]    [4, 64, 56, 56]      --                   --
# ├─Sequential (layer1)                              [4, 64, 56, 56]      [4, 256, 56, 56]     --                   True
# │    └─Block (0)                                   [4, 64, 56, 56]      [4, 256, 56, 56]     --                   True
# ...

# %%
resnet101 = load_resnet.ResNet101()
load_resnet.summarize(resnet101, (4, 3, 224, 224))
# Out:
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                                    [4, 3, 224, 224]     [4, 1000]            --                   True
# ├─Conv2d (conv1)                                   [4, 3, 224, 224]     [4, 64, 112, 112]    9,472                True
# ├─BatchNorm2d (bn1)                                [4, 64, 112, 112]    [4, 64, 112, 112]    128                  True
# ├─ReLU (relu)                                      [4, 64, 112, 112]    [4, 64, 112, 112]    --                   --
# ├─MaxPool2d (maxpool)                              [4, 64, 112, 112]    [4, 64, 56, 56]      --                   --
# ├─Sequential (layer1)                              [4, 64, 56, 56]      [4, 256, 56, 56]     --                   True
# │    └─Block (0)                                   [4, 64, 56, 56]      [4, 256, 56, 56]     --                   True
# ...

# %%
resnet152 = load_resnet.ResNet152()
load_resnet.summarize(resnet152, (4, 3, 224, 224))
# Out:
# ...
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ...
# ResNet (ResNet)                                    [4, 3, 224, 224]     [4, 1000]            --                   True
# ├─Conv2d (conv1)                                   [4, 3, 224, 224]     [4, 64, 112, 112]    9,472                True
# ├─BatchNorm2d (bn1)                                [4, 64, 112, 112]    [4, 64, 112, 112]    128                  True
# ├─ReLU (relu)                                      [4, 64, 112, 112]    [4, 64, 112, 112]    --                   --
# ├─MaxPool2d (maxpool)                              [4, 64, 112, 112]    [4, 64, 56, 56]      --                   --
# ├─Sequential (layer1)                              [4, 64, 56, 56]      [4, 256, 56, 56]     --                   True
# │    └─Block (0)                                   [4, 64, 56, 56]      [4, 256, 56, 56]     --                   True
# ...
